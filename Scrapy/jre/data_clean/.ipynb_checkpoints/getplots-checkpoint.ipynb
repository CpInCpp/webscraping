# %%
# this code will hide the coding cells..
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
# import 
import pandas as pd
from matplotlib import pyplot as plt
from IPython.display import HTML
df = pd.read_csv('jre2_clean.csv')

# %%
# a few cleaning bits..
# get rid of the episode number from the title
df['ep_title'] = df.ep_title.str.replace('\\#\d{1,4}- ', '')
# drop 'best of' episodes, episodes less than 55 min, and fight companion episodes..
mask1 = ~df.ep_title.str.contains('Best of')
mask2 = df.runtime > 55
mask3 = ~df.ep_title.str.contains('Fight Companion')
df = df[mask1&mask2&mask3]

# %%
# change the date format using pd.to_datetime(), and then set the airdate as index.
df['airdate'] = pd.to_datetime(df.airdate)
df = df.set_index('airdate')

# %%
# create two separate data frames: 1 with no tag column, and one with tag column.  Then drop the duplicates from the dataframe
dft = df.copy()
df = df.drop('tag', axis = 1)
df = df.drop_duplicates()

# %%
# plot time series of views
# need to format the plot.  label y axis, and get more tick marks, maybe...
cols = ['views', 'likes', 'dislikes']
axes = df[cols].plot(title = 'Number of Views Since the Beginning', figsize=(10,10), subplots = True, legend = False, grid = True)
# There are a few spikes that are interesting.  Who are these people receving so many views?
plt.subplots_adjust(top=.95, left=.25)
#plt.ylabel(['Dislikes', 'Likes', 'Views (10 Mil)'])
i = 0
for ax in axes:
    ax.set_ylabel(cols[i])
    i += 1

# %%
# these will return df for ranges in which spikes occur:
t1 = df['2015-06':'2016-01'].nlargest
t2 = df['2017-01':'2017-03']
t3 = df['2017-06':'2017-09']
t4 = df['2018-06':'2019-01']
t5 = df['2019-01':]

# %%
t5.nlargest(10, 'dislikes')
# Out:
#                 ep                              ep_title  runtime     views  \
# airdate
# 2019-02-02  1236.0                           Jack Dorsey   115.13   1575178
# 2019-01-22  1228.0                            Bari Weiss   172.32   1149860
# 2019-04-17  1282.0                          Adam Conover   167.22   1564034
# 2019-02-28  1255.0                   Alex Jones Returns!   280.47  14498419
# 2019-06-26  1316.0                           Abby Martin   136.68   1551028
# 2019-03-13  1263.0                         Renée DiResta   127.92    964511
# 2019-03-07  1259.0                   David Wallace-Wells   113.58   1158346
# 2019-06-06  1311.0                          David Pakman   125.38   1653621
# 2019-03-06  1258.0  Jack Dorsey, Vijaya Gadde & Tim Pool   205.18   3543086
# 2019-02-08  1241.0                            Sam Harris   163.02   2682136
#
#              likes  dislikes  ratio
# airdate
# 2019-02-02   13684     86622   0.16
# 2019-01-22   12983     29676   0.44
# 2019-04-17   19395     27119   0.72
# 2019-02-28  346023     13288  26.04
# 2019-06-26   21480     12221   1.76
# 2019-03-13    9735     11104   0.88
# 2019-03-07   14082      9616   1.46
# 2019-06-06   27253      7753   3.52
# 2019-03-06   84608      7596  11.14
# 2019-02-08   37204      7319   5.08

# %%
ax.plot(df.loc['2017-01':'2017-02', 'Consumption'], marker='o', linestyle='-')
ax.set_ylabel('Views (10 mil)')
ax.set_title('Number of Views Since the Beginning')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-1e352d5a47bf> in <module>
# ----> 1 fig, ax = plt
#       2 ax.plot(df.views)
#       3 ax.set_ylabel('Views (10 mil)')
#       4 ax.set_title('Number of Views Since the Beginning')
#
# TypeError: cannot unpack non-iterable module object

# %%
df1 = df['2015-06':'2016-01'].nlargest(20, 'views')

df1.groupby('ep_title').views.mean().sort_values(ascending=False).plot.bar(color='b')

# %%
dft.groupby('tag').views.mean().sort_values(ascending=False).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-170-6beafd79e7b3> in <module>
# ----> 1 dft.groupby('tag').views.sort_values(ascending=False).plot.bar()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'sort_values' of 'SeriesGroupBy' objects, try using the 'apply' method

# %%
dft.sample(100)
# Out:
#                 ep                                           ep_title  \
# airdate
# 2017-05-04   955.0                                        Al Madrigal
# 2014-02-05   449.0                                  Justin Martindale
# 2013-06-01   256.0                                       David Seaman
# 2018-11-16  1204.0                                     Steven Rinella
# 2018-05-22    27.0                                        Robin Black
# 2014-04-09   482.0                      Rob MacCachren & Bud Brutsman
# 2014-04-15   485.0                                        Amy Schumer
# 2013-03-28   181.0                                   Iliza Shlesinger
# 2014-12-09   584.0                                      Zoltan Istvan
# 2013-11-05   411.0                                        Dave Asprey
# 2019-04-24  1285.0                                             B-Real
# 2013-05-05   217.0                                    Michael Ruppert
# 2016-09-20   848.0                                       Bryan Callen
# 2013-02-07   323.0                                “Freeway” Rick Ross
# 2013-01-18    17.0                           Ari Shaffir, Eddie Bravo
# 2013-06-04   363.0                                           Everlast
# 2017-09-22  1013.0                                      Cameron Hanes
# 2017-02-24   922.0                                    Philip DeFranco
# 2014-04-30   492.0                                        Dave Attell
# 2014-08-06   531.0                                       Nick Youssef
# 2017-04-20   949.0                                         Josh Zepps
# 2016-01-22   750.0  Kip Andersen & Keegan Kuhn, producers of Cowsp...
# 2019-01-12  1223.0                                   Greg Fitzsimmons
# 2018-09-28  1176.0                      Dom D’Agostino & Layne Norton
# 2015-11-19   725.0                   Graham Hancock & Randall Carlson
# 2015-11-05   719.0                                          Josh Olin
# 2014-11-22   578.0                                       Peter McGraw
# 2013-05-31   244.0                                 Immortal Technique
# 2013-01-17   292.0                                        Eddie Bravo
# 2019-03-20  1267.0                      Gary Taubes & Stephan Guyenet
# ...            ...                                                ...
# 2017-12-19  1054.0                                 Dr. Rhonda Patrick
# 2016-10-25   864.0                        Kevin Ross & Gaston Bolanos
# 2013-01-20    58.0                        Mayhem Miller, Brian Redban
# 2016-03-02   767.0                                         Mike Baker
# 2017-04-11   944.0                     Scott Eastwood & Cameron Hanes
# 2013-01-23   134.0                 Kevin Smith, Brian Redban (Part 3)
# 2018-02-14  1078.0                                         Jimmy Dore
# 2014-10-23   566.0                                         Sue Aikens
# 2017-12-06  1048.0                                      Doug Stanhope
# 2013-02-01   142.0                    Graham Hancock, Duncan Trussell
# 2019-02-13  1246.0        Pot Debate Alex Berenson & Dr. Michael Hart
# 2015-07-23   673.0                         Nick DiPaolo & Adam Lowery
# 2017-09-28  1016.0                                   Whitney Cummings
# 2019-07-02  1319.0                                          Joey Diaz
# 2013-02-08   271.0                                        London Real
# 2013-01-23   134.0                 Kevin Smith, Brian Redban (Part 2)
# 2017-04-19   948.0                       Brendan Schaub & Eddie Bravo
# 2014-07-18   523.0                                         Jim Norton
# 2016-01-21   749.0                     Carlos Condit & Erwan Le Corre
# 2015-10-15   708.0                           Steven Crowder  politics
# 2018-10-24  1187.0                            Kyle Kulinski  politics
# 2016-11-08   869.0                               Dave Rubin  politics
# 2014-05-13   499.0                               Cenk Uygur  politics
# 2016-05-17   801.0                             Gary Johnson  politics
# 2017-04-20   949.0                               Josh Zepps  politics
# 2015-10-27   713.0                               Dave Rubin  politics
# 2016-08-24   838.0                               Josh Zepps  politics
# 2016-05-10   796.0                               Josh Zepps  politics
# 2014-01-07   436.0                          Stefan Molyneux  politics
# 2015-11-23   726.0                               Josh Zepps  politics
# 2014-12-03   582.0                             David Seaman  politics
# 2013-05-30   239.0                              Adam Kokesh  politics
# 2014-07-08   520.0                             David Seaman  politics
# 2014-11-11   571.0                               Josh Zepps  politics
# 2014-04-17   487.0                             David Seaman  politics
# 2013-06-20   368.0                             David Seaman  politics
# 2013-02-08   276.0  David Seaman, Abby Martin, Dell Cameron  politics
# 2013-06-01   256.0                             David Seaman  politics
#
#             runtime     views   likes  dislikes  ratio
# airdate
# 2017-08-03   159.23  13444126  172795     12582  13.73
# 2017-02-02   223.05   9383993  152809      7855  19.45
# 2016-10-14   131.37   3790544   38945      2906  13.40
# 2017-02-16   237.30   3709555   37044     10782   3.44
# 2018-01-31   147.88   3472520   49580      4328  11.46
# 2015-10-01   174.28   2828309   33131      3526   9.40
# 2016-07-07   175.32   2135954   28187      3247   8.68
# 2019-05-14   154.80   2085641   48972      5773   8.48
# 2018-04-19   118.07   2035513   28262      2429  11.64
# 2018-06-13   177.22   1862803   24215      4111   5.89
# 2018-02-28   181.43   1859978   27858      3845   7.25
# 2018-02-14   170.65   1786590   27615      3026   9.13
# 2018-02-26   116.30   1702891   24194      1763  13.72
# 2018-08-10   137.47   1597884   24385      3193   7.64
# 2015-10-15   178.60   1341143   13015      2216   5.87
# 2018-10-24   163.68   1174038   20668      3610   5.73
# 2016-11-08   209.67    692526    8699       525  16.57
# 2014-05-13   174.38    602106    7148      3797   1.88
# 2016-05-17   153.15    564831    8354       480  17.40
# 2017-04-20   175.07    460583    4291      4068   1.05
# 2015-10-27   180.23    429829    6267       396  15.83
# 2016-08-24   193.55    305701    2113       235   8.99
# 2016-05-10   145.00    233969    1559       247   6.31
# 2014-01-07   173.93    175848    2323       546   4.25
# 2015-11-23    96.08    149212    1460       143  10.21
# 2014-12-03   181.12    101476     650       118   5.51
# 2013-05-30   172.18     84479    1046        65  16.09
# 2014-07-08   179.73     79115     582        80   7.28
# 2014-11-11   139.50     79010     713        90   7.92
# 2014-04-17   170.00     74033     509        56   9.09
# 2013-06-20   148.15     55925     595        41  14.51
# 2013-02-08   174.78     23457     256        20  12.80
# 2013-06-01   179.57      8499      93         4  23.25

# %%
# assign a slice to dft_politics and create a new column in it called 'political lean'
dft_politics = dft[dft.tag == 'politics']
dft_politics = {'Ben Shapiro' : 'conservative', 'Alex Jones' : 'far-right', 'Jesse Ventura' : 'reform', 'Steven Crowder' : 'conservative', 'Milo Yiannopoulos' : 'libertarian', 'Tulsi Gabbard' : 'democrat', 'Sam Harris' : 'liberal', 'Dave Rubin' : 'conservative', 'Kyle Kulinsky' : 'democrat', 'Jimmy Dore' : 'democrat' : 'Douglas Murray' : 'conservative', 'Cenk Uygur' : 'progressive', 'Gary Johnson' : 'libertarian', 'Josh Zepps' : 'satirist', 'Stefan Molyneux' : 'far right', 'David Seaman' : ''}

# %%
# plot ratio and views with same time series, and facet them..
taglist = ['politics', 'activists', 'writers', 'athletes-fighters-martial-arts', 'comedians', 'business', 'musicians']
#taglist = dft.tag.unique().tolist()
Views = sns.FacetGrid(dft[dft.tag.isin(taglist)], col='tag', col_wrap = 3, hue="tag", palette="Set1", height=4, xlim=(0,1e5))
Views.map(sns.distplot, "likes")

# %%
df['likes'].plot(legend = True)
df['dislikes'].plot(legend=True)

# %%
# who are the top 10 of all time?
df.nlargest(10, 'views')
# Out:
#                 ep                  ep_title            tag  runtime  \
# airdate
# 2018-09-07  1169.0                 Elon Musk       business   157.05
# 2019-02-28  1255.0       Alex Jones Returns!  miscellaneous   280.47
# 2017-08-03   993.0               Ben Shapiro        authors   159.23
# 2017-08-03   993.0               Ben Shapiro       politics   159.23
# 2017-08-03   993.0               Ben Shapiro        writers   159.23
# 2017-02-22   919.0       Neil deGrasse Tyson        authors   134.42
# 2018-08-23  1159.0       Neil deGrasse Tyson        authors   201.15
# 2017-02-02   911.0  Alex Jones & Eddie Bravo     filmmakers   223.05
# 2017-02-02   911.0  Alex Jones & Eddie Bravo      musicians   223.05
# 2017-02-02   911.0  Alex Jones & Eddie Bravo       politics   223.05
#
#                views   likes  dislikes  ratio
# airdate
# 2018-09-07  23500042  490622     11129  44.09
# 2019-02-28  14498419  346023     13288  26.04
# 2017-08-03  13444126  172795     12582  13.73
# 2017-08-03  13444126  172795     12582  13.73
# 2017-08-03  13444126  172795     12582  13.73
# 2017-02-22  10607970  127137      8217  15.47
# 2018-08-23   9771788  123174      6960  17.70
# 2017-02-02   9383993  152809      7855  19.45
# 2017-02-02   9383993  152809      7855  19.45
# 2017-02-02   9383993  152809      7855  19.45

# %%
# let's see all political guests..
mask1 = ~df.ep.isna()
mask2 = df.tag=='miscellaneous'
mask3 = df.runtime > 60

df[mask1&mask2&mask3]
# Out:
#                 ep                                           ep_title  \
# airdate
# 2019-06-21  1315.0                         Bob Lazar & Jeremy Corbell
# 2019-06-20  1314.0                Charlamagne tha God & Andrew Schulz
# 2019-06-06  1311.0                                       David Pakman
# 2013-01-23   125.0    Giorgio A. Tsoukalos, Eddie Bravo, Brian Redban
# 2013-01-21    96.0                        Kevin Pereira, Brian Redban
# 2013-10-01   399.0                                         Buck Angel
# 2013-06-22   369.0          Jason Silva, Duncan Trussell, Ari Shaffir
# 2013-06-03   270.0                                      Kevin Pereira
# 2013-05-29   232.0                                  Giorgio Tsoukalos
# 2013-05-22   359.0                                          Alex Grey
# 2013-04-10   194.0                                        Jason Silva
# 2013-02-26   328.0                                         Dan Carlin
# 2013-02-08   274.0                                          Alex Grey
# 2013-02-01   148.0                                      Kevin Pereira
# 2014-03-04   463.0                                      Louis Theroux
# 2014-01-07   436.0                                    Stefan Molyneux
# 2013-11-13   416.0                                      Ana Kasparian
# 2013-11-09   413.0                        Dan Carlin, Daniele Bolelli
# 2014-07-16   521.0                          Lewis, from Unbox Therapy
# 2014-07-01   517.0                              Crash, from Float Lab
# 2014-07-01   517.0                     Crash, from Float Lab (Part 2)
